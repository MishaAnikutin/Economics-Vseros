# %% [markdown]
# # Экономика. Всероссийская олимпиада школьников
#
# все исследования всероса

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px 
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['font.family'] = 'Inter'
# %matplotlib inline

import string
import random

# %%
PATH = r'C:\Users\billy\OneDrive\Рабочий стол\data\Экономика\всерос'
COLOR = '#2F80ED'
GREY = '#BDBDBD'
GREEN = '#219653'
LIGHTGREEN = '#6FCF97'
LIGHT_COLOR = '#abccf8'

# %%
def RGB_TO_HEX(r, g, b):
    return '#%02x%02x%02x' % (r, g, b)

# %% [markdown]
# ## Результативность регионов на ЗЭ ВОШ

# %%
new_path = r'C:\Users\billy\OneDrive\Рабочий стол\data\Общее'

df = pd.read_csv(new_path + r'\Рейтинг регионов по итогам Всероссийской олимпиады 2023 года.txt', sep='\t')

# %%
for year in ['2015', '2017', '2019', '2021', '2022', '2023']:
    df[year] =  df[year].apply(lambda x: x.replace(',', '.')).astype(float)

# %%
df[df['Регион'] == 'Республика Татарстан'].index[0]
# Out:
# 1

# %%
COLOR
# Out:
# '#2F80ED'

# %%
from colour import Color
colors = list(map(lambda x: x.hex,
    Color("white").range_to(Color(COLOR), steps=6)
))[1:]

# %%
colors
# Out:
# ['#eceae5', '#d4e1c3', '#99dda3', '#68e1d0', '#2f80ed']

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=200)

ax.yaxis.tick_right()

ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)


x = [2015, 2017, 2019, 2021, 2022, 2023]
for region in df.iloc[:5]['Регион']:
    y = df[df['Регион'] == region].iloc[0, 2:]
    
    index = df[df['Регион'] == region].index[0]
    
    ax.plot(x, y, linewidth=3, color=colors[index])
        
    plt.text(s=f" {index + 1}) {region} ", x=x[-1] + 0.2, y=y[-1], 
             color='white',
             fontdict={'font': 'inter', 'weight': 'bold'},
             bbox={'facecolor': COLOR, 'edgecolor': COLOR}
    )
    
ax.set_xlim(2015, 2023)
    
# ax.grid(
#     axis='x',
#     color='lightgrey'
# )
# Out:
# (2015.0, 2023.0)

# %% [markdown]
# # Результативность стран на IEO

# %%
df = pd.read_excel(r'C:\Users\billy\OneDrive\Рабочий стол\data\Экономика\Межнар 2023.xlsx')

# %%
df.head(3)
# Out:
#    Unnamed: 0                     Name Surname    Country  Financial Literacy  \
# 0           1                   Daniel   Zhang     Canada              42.349
# 1           2                      Alp  Yalçın    Türkiye              46.809
# 2           3  Muhammad Amadeus Ihsan   Candra  Indonesia              47.447
#
#    Economics  Business Case    Total Award
# 0    100.000         40.905  183.253  Gold
# 1     93.250         40.905  180.964  Gold
# 2     95.766         32.952  176.166  Gold

# %%
df.Award.unique()
# Out:
# array(['Gold', 'Silver', 'Bronze', nan], dtype=object)

# %%
# Out:
#            0
# 0  Argentina
# 1          0
# 2          0
# 3          0

# %%
a = pd.DataFrame(columns=['Country', 'Gold', 'Silver', 'Bronze'])
    
for i, country in enumerate(df.Country.unique()):
    gold = df[(df.Country == country) & (df.Award == 'Gold')].shape[0]
    silver = df[(df.Country == country) & (df.Award == 'Silver')].shape[0]
    bronze = df[(df.Country == country) & (df.Award == 'Bronze')].shape[0]
    tmp = pd.DataFrame({'Country': country, 'Gold': gold, 'Silver': silver, 'Bronze': bronze}, index=[i])
    
    a = pd.concat([a, tmp])

# %%
a = a.sort_values(by=['Gold', 'Silver', 'Bronze'], ascending=False).reset_index(drop=True)
a = a.reset_index().rename(columns={'index': 'place'})

# %%
df['Place'] = df['Country'].apply(lambda x: a[a.Country == x].place.iloc[0] + 1)

# %%
import joypy
from matplotlib import cm

# %%
df\
    .groupby('Country', as_index=False)\
    .agg({'Business Case': 'mean'})\
    .sort_values(by='Business Case', ascending=False)\
    .reset_index(drop=True).head(5)
# Out:
#      Country  Business Case
# 0  Hong Kong         46.585
# 1   Malaysia         43.177
# 2     Taiwan         42.041
# 3  Singapore         40.905
# 4    Romania         40.905

# %%
df.head(1)
# Out:
#    Unnamed: 0    Name Surname Country  Financial Literacy  Economics  \
# 0           1  Daniel   Zhang  Canada              42.349      100.0
#
#    Business Case    Total Award  Place
# 0         40.905  183.253  Gold      3

# %%
tmp = df[df.Country == 'Russia']

# %%
tmp = df
tmp.head(3)
# Out:
#    Unnamed: 0                     Name Surname    Country  Financial Literacy  \
# 0           1                   Daniel   Zhang     Canada              42.349
# 1           2                      Alp  Yalçın    Türkiye              46.809
# 2           3  Muhammad Amadeus Ihsan   Candra  Indonesia              47.447
#
#    Economics  Business Case    Total Award  Place
# 0    1.00000         40.905  183.253  Gold      3
# 1    0.93250         40.905  180.964  Gold      9
# 2    0.95766         32.952  176.166  Gold      1

# %%
tmp['Economics'] = (tmp['Economics'] - tmp['Economics'].min()) / (tmp['Economics'].max() - tmp['Economics'].min())
tmp['Financial Literacy'] = (tmp['Financial Literacy'] - tmp['Financial Literacy'].min()) / (tmp['Financial Literacy'].max() - tmp['Financial Literacy'].min())
tmp['Business Case'] = (tmp['Business Case'] - tmp['Business Case'].min()) / (tmp['Business Case'].max() - tmp['Business Case'].min())

# %%
fig, ax = plt.subplots(figsize=(5, 4), dpi=200)

for spine in ax.spines:
    if spine != 'bottom': ax.spines[spine].set_visible(False)

tmp = tmp[tmp.Country == 'Russia']
        
ax.bar(
    x=tmp.Name,
    height=tmp['Business Case'],
    color=COLOR,
    label='Business Case',
    zorder=2
)

ax.bar(
    x=tmp.Name,
    height=tmp['Financial Literacy'],
    bottom=tmp['Business Case'],
    color=COLOR,
    alpha=0.7,
    label='Financial Literacy',
    zorder=2
)

ax.bar(
    x=tmp.Name,
    height=tmp['Economics'],
    bottom=tmp['Business Case'] + tmp['Financial Literacy'],
    color=COLOR,
    alpha=0.3,
    label='Economics',
    zorder=2
)

ax.legend()
ax.grid(axis='y', color='lightgrey', alpha=0.5, zorder=0)

plt.title('Results of the Russian national team at the IEO')
# Out:
# Text(0.5, 1.0, 'Results of the Russian national team at the IEO')

# %%
tmp = a[a.place <= 9].sort_values(by=['Gold', 'Silver', 'Bronze'], ascending=True)

fig, ax = plt.subplots(figsize=(5, 4), dpi=200)

for spine in ax.spines:
    if spine != 'bottom': ax.spines[spine].set_visible(False)

ax.barh(
    y=tmp.Country,
    width=tmp.Bronze,
    color='#cd7f32'
)

ax.barh(
    y=tmp.Country,
    width=tmp.Silver,
    left=tmp.Bronze,
    color='silver'
)

ax.barh(
    y=tmp.Country,
    width=tmp.Gold,
    left=tmp.Bronze + tmp.Silver,
    color='gold',
)

ax.set_xlim([0, 6])
# Out:
# (0.0, 6.0)

# %%
fig, ax = plt.subplots(dpi=200)

joypy.joyplot(
    df[df.Place < 10].groupby('Place', sort=True),
    column='Total',
#     by='Country',
    hist=True,
    color=COLOR,
    histtype='stepfilled',
    ax=ax
)

plt.xlabel('Суммарный балл')
plt.show()
# Out:
# C:\Users\billy\anaconda3\lib\site-packages\joypy\joyplot.py:435: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   fig, axes = _subplots(naxes=num_axes, ax=ax, squeeze=False,

# %% [markdown]
# # Поступление всеросников по экономике

# %%
df = pd.read_excel(PATH + '\куда поступают со всеросом.xlsx')
df.columns = ['time', 'name', 'program']
df = df.drop_duplicates('name')
df['tmp'] = [1] * df.shape[0]

# %%
tmp = pd.DataFrame()

# %%
pd.DataFrame(tmp)
# Out:
#                                               program  count
# 0   Международный институт экономики и финансов, Н...      6
# 1                  Экономика и анализ данных, НИУ ВШЭ      7
# 2                    Совместный бакалавриат ВШЭ и РЭШ     13
# 3                               Другие программы МФТИ      1
# 4                               Другие программы МФТИ      1
# 5                            Другие программы НИУ ВШЭ      1
# 6                               Другие программы МФТИ      1
# 7                               Другие программы МФТИ      1
# 8                            Другие программы НИУ ВШЭ      1
# 9                            Другие программы НИУ ВШЭ      1
# 10                              Другие программы МФТИ      1
# 11                              Другие программы МФТИ      1
# 12                              Другие программы МФТИ      1

# %%
tmp = df.groupby('program', as_index=False).agg('count')

# %%
tmp.drop(columns=['time', 'name'], inplace=True)

# %%
tmp['percent'] = tmp['tmp'] / 36 * 100

# %%
tmp
# Out:
#                                               program  tmp    percent
# 0                     Анализ данных в экономике, МФТИ    1   2.777778
# 1                         Бизнес информатика, НИУ ВШЭ    1   2.777778
# 2                                             ВШЭ ПМИ    1   2.777778
# 3                                            ЛФИ МФТИ    1   2.777778
# 4                                           ЛФИ, МФТИ    1   2.777778
# 5   МФТИ ПМФ - "Математическое моделирование и ком...    1   2.777778
# 6                                         Матфак ВШЭ     1   2.777778
# 7   Международный институт экономики и финансов, Н...    6  16.666667
# 8                                            ПМФ МФТИ    1   2.777778
# 9                    Совместный бакалавриат ВШЭ и РЭШ   13  36.111111
# 10                                          ФПМИ МФТИ    1   2.777778
# 11                                       ФПМИ ПМИ.РЭШ    1   2.777778
# 12                 Экономика и анализ данных, НИУ ВШЭ    7  19.444444

# %%
df.to_csv(PATH + '/куда поступают со всеросом.csv')

# %% [markdown]
# # Регион 2022 - регион 2023

# %%
temp1 = pd.read_csv(PATH + f'\\РЭ ВОШ Экономика 2020.csv', sep='\t')
temp2 = pd.read_csv(PATH + f'\\РЭ ВОШ Экономика 2021.csv', sep='\t')
temp3 = pd.read_csv(PATH + f'\\РЭ ВОШ Экономика 2022.csv', sep='\t')
temp4 = pd.read_csv(PATH + f'\\РЭ ВОШ Экономика 2023.csv', sep='\t')

# %%
temp1['год'] = 2020
temp2['год'] = 2021
temp3['год'] = 2022
temp4['год'] = 2023

# %%
temp1 = temp1.rename(columns={'Сумма': 'Балл'})
temp1 = temp1.dropna()

# %%
temp = temp1.merge(temp2, on='Ф.И.О.')
temp = pd.concat([temp, temp2.merge(temp3, on='Ф.И.О.'), temp3.merge(temp4, on='Ф.И.О.')])

# %%
temp['Балл_x'].corr(temp['Балл_y'])
# Out:
# 0.6429829890998161

# %%
plt.scatter(temp['Балл_x'], temp['Балл_y'])

plt.xlabel('балл на регионе прошлого года')
plt.ylabel('балл на регионе следующего года')
# Out:
# Text(0, 0.5, 'балл на регионе следующего года')

# %%
fig, ax = plt.subplots(figsize=(10, 6), dpi=150)

[ax.spines[spine].set_visible(False) for spine in ax.spines if spine != 'bottom']

ax.set_xlim(['2022', '2023'])
ax.set_ylim([0, 200])

ax.plot(['2022', '2022'], [0, 200], linewidth=3, color='black')
ax.plot(['2023', '2023'], [0, 200], linewidth=3, color='black')

for i in range(df.shape[0]):
    x_1 = df['Балл_x'].iloc[i]
    x_0 = df['Балл_y'].iloc[i]
    ax.plot(['2022', '2023'], [x_0, x_1], color='grey', alpha=0.05, linewidth=5)
    
plt.title('Балл на регионе 2022 и на регионе 2023\n\n', loc='left')
# Out:
# Text(0.0, 1.0, 'Балл на регионе 2022 и на регионе 2023\n\n')

# %%
sns.kdeplot(temp[temp['год_x'] == 2020]['Балл_x'])
sns.kdeplot(temp[temp['год_x'] == 2021]['Балл_x'])
sns.kdeplot(temp[temp['год_x'] == 2022]['Балл_x'])
sns.kdeplot(temp[temp['год_y'] == 2023]['Балл_y'])
# Out:
# <Axes: xlabel='Балл_x', ylabel='Density'>
